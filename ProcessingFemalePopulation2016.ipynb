# %% [markdown]
# # Census Project

# %% [markdown]
# ## Processing Female data

# %% [markdown]
# Reading data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

df = pd.read_csv('data/CensusLocalAreaProfiles2016_cleaned.csv', encoding='ISO-8859-1')

# %% [markdown]
# Selecting female data

# %%
df1 = df.iloc[54:78, 0:25]

# %% [markdown]
# Creating a new data frame

# %%
df1.shape
# Out:
# (24, 25)

# %% [markdown]
# Apperance of the dataframe

# %%
df1.head(26)
# Out:
#     Unnamed: 0  ID                    Variable Arbutus-Ridge Downtown  \
# 54          54  55                0 to 4 years           220     1000
# 55          55  56                5 to 9 years           340      530
# 56          56  57              10 to 14 years           400      390
# 57          57  58              15 to 64 years          5350    23805
# 58          58  59              15 to 19 years           580      580
# 59          59  60              20 to 24 years           615     2150
# 60          60  61              25 to 29 years           405     4535
# 61          61  62              30 to 34 years           290     4570
# 62          62  63              35 to 39 years           335     2905
# 63          63  64              40 to 44 years           615     2060
# 64          64  65              45 to 49 years           800     1960
# 65          65  66              50 to 54 years           690     1780
# ...

# %% [markdown]
# Deleting rows with information not needed

# %%
df2 = df1.drop([57,68,73])

# %%
df2.to_csv('data/CensusFemale2016.csv')

# %% [markdown]
# Reading dataframe created

# %%
df3 = pd.read_csv('data/CensusFemale2016.csv', encoding='ISO-8859-1')

# %% [markdown]
# Determining if dataframe is empty

# %%
df3.empty
# Out:
# False

# %% [markdown]
# Dimensions of the dataframe

# %%
df3.shape
# Out:
# (21, 26)

# %% [markdown]
# Size of the File CensusMale2016.csv

# %%
# !dir data\CensusFemale2016.csv
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is 4623-A251
#
#  Directory of C:\Users\Jhonny\DataAnalysis\Census\data
#
# 2019-12-07  11:16 PM             2,879 CensusFemale2016.csv
#                1 File(s)          2,879 bytes
#                0 Dir(s)  328,803,012,608 bytes free

# %% [markdown]
# Determining permision of the file

# %%
# !icacls data\CensusLocalAreaProfiles2016.csv
# Out:
# data\CensusLocalAreaProfiles2016.csv NT AUTHORITY\SYSTEM:(I)(F)
#                                      BUILTIN\Administrators:(I)(F)
#                                      MARIA\Jhonny:(I)(F)
#                                      MARIA\Christy:(I)(F)
#
# Successfully processed 1 files; Failed processing 0 files

# %%
df3.head(26)
# Out:
#     Unnamed: 0  Unnamed: 0.1  ID                    Variable  Arbutus-Ridge  \
# 0           54            54  55                0 to 4 years            220
# 1           55            55  56                5 to 9 years            340
# 2           56            56  57              10 to 14 years            400
# 3           58            58  59              15 to 19 years            580
# 4           59            59  60              20 to 24 years            615
# 5           60            60  61              25 to 29 years            405
# 6           61            61  62              30 to 34 years            290
# 7           62            62  63              35 to 39 years            335
# 8           63            63  64              40 to 44 years            615
# 9           64            64  65              45 to 49 years            800
# 10          65            65  66              50 to 54 years            690
# ...

# %% [markdown]
# The column "Unnamed" is not necessary and the column "ID" is incorret. Both columns Unnamed and ID should be remove it.

# %% [markdown]
# Deleting column Unnamed

# %%
del df3['Unnamed: 0']
del df3['Unnamed: 0.1']

# %% [markdown]
# Checking the dataset

# %%
df3.head(26)
# Out:
#     ID                    Variable  Arbutus-Ridge  Downtown  \
# 0   55                0 to 4 years            220      1000
# 1   56                5 to 9 years            340       530
# 2   57              10 to 14 years            400       390
# 3   59              15 to 19 years            580       580
# 4   60              20 to 24 years            615      2150
# 5   61              25 to 29 years            405      4535
# 6   62              30 to 34 years            290      4570
# 7   63              35 to 39 years            335      2905
# 8   64              40 to 44 years            615      2060
# 9   65              45 to 49 years            800      1960
# 10  66              50 to 54 years            690      1780
# 11  67              55 to 59 years            510      1795
# 12  68              60 to 64 years            515      1475
# 13  70              65 to 69 years            485      1250
# 14  71              70 to 74 years            360       775
# ...

# %% [markdown]
# Deleting column ID

# %%
del df3['ID']

# %% [markdown]
# Checking the dataset

# %%
df3.head(26)
# Out:
#                       Variable  Arbutus-Ridge  Downtown  Dunbar-Southlands  \
# 0                 0 to 4 years            220      1000                325
# 1                 5 to 9 years            340       530                580
# 2               10 to 14 years            400       390                810
# 3               15 to 19 years            580       580                870
# 4               20 to 24 years            615      2150                840
# 5               25 to 29 years            405      4535                535
# 6               30 to 34 years            290      4570                365
# 7               35 to 39 years            335      2905                445
# 8               40 to 44 years            615      2060                795
# 9               45 to 49 years            800      1960               1120
# 10              50 to 54 years            690      1780                955
# ...

# %%
df3.columns
# Out:
# Index(['Variable', 'Arbutus-Ridge', 'Downtown', 'Dunbar-Southlands',
#        'Fairview', 'Grandview-Woodland', 'Hastings-Sunrise',
#        'Kensington-Cedar Cottage', 'Kerrisdale', 'Killarney', 'Kitsilano',
#        'Marpole', 'Mount Pleasant', 'Oakridge', 'Renfrew-Collingwood',
#        'Riley Park', 'Shaughnessy', 'South Cambie', 'Strathcona', 'Sunset',
#        'Victoria-Fraserview', 'West End', 'West Point Grey'],
#       dtype='object')

# %% [markdown]
# Fast visual first QC of the data to detect errors, missing values, anomalies,etc

# %% [markdown]
# Plotting ID

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
df3.Variable
# Out:
# 0                   0 to 4 years
# 1                   5 to 9 years
# 2                 10 to 14 years
# 3                 15 to 19 years
# 4                 20 to 24 years
# 5                 25 to 29 years
# 6                 30 to 34 years
# 7                 35 to 39 years
# 8                 40 to 44 years
# 9                 45 to 49 years
# 10                50 to 54 years
# 11                55 to 59 years
# 12                60 to 64 years
# 13                65 to 69 years
# 14                70 to 74 years
# 15                75 to 79 years
# 16                80 to 84 years
# 17                85 to 89 years
# 18                90 to 94 years
# 19                95 to 99 years
# 20            100 years and over
# Name: Variable, dtype: object

# %% [markdown]
# Plotting Arbutus-Ridge

# %%
df3.plot(kind='bar',x='Variable',y='Arbutus-Ridge',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Downtown',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Dunbar-Southlands',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Fairview',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Grandview-Woodland',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Kensington-Cedar Cottage',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Kerrisdale',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Kensington-Cedar Cottage',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Hastings-Sunrise',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Kitsilano',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Marpole',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Mount Pleasant',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Oakridge',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Renfrew-Collingwood',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Riley Park',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Shaughnessy',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='South Cambie',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Strathcona',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Sunset',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='Victoria-Fraserview',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='West End',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

df3.plot(kind='bar',x='Variable',y='West Point Grey',color='green')
plt.ylabel('Number of People')
plt.xlabel('Age range')

plt.show()
# Out:
# C:\Users\Jhonny\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
